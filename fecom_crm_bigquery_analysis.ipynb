# %% [markdown]
# Bigquery Setup

# %%
from google.cloud import bigquery
import pandas as pd
import numpy as pd
import os 

#initialise the Bigquery client (API that makes BigQuery and Python intercact)
client = bigquery.Client(project='sql-sandbox-435415')
